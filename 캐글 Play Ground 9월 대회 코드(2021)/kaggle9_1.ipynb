# %%
import pandas as pd

train = pd.read_csv('kaggle9/train.csv')
test = pd.read_csv('kaggle9/test.csv')

# %%
train.describe()
# Out:
#                   id             f1             f2             f3  \
# count  957919.000000  942672.000000  942729.000000  942428.000000
# mean   478959.000000       0.090201       0.345964    4068.744207
# std    276527.540593       0.043564       0.146251    6415.829440
# min         0.000000      -0.149910      -0.019044   -9421.700000
# 25%    239479.500000       0.070227       0.283050     418.430000
# 50%    478959.000000       0.090135       0.389100    1279.500000
# 75%    718438.500000       0.116500       0.458450    4444.400000
# max    957918.000000       0.415170       0.518990   39544.000000
#
#                   f4             f5             f6             f7  \
# count  942359.000000  942514.000000  942398.000000  942415.000000
# mean        0.201214       0.304869      -0.071458    1620.843815
# std         0.212510       0.145343       2.123777    1276.281403
# min        -0.082122      -0.006990     -12.791000    -224.800000
# ...

# %%
from sklearn.model_selection import train_test_split

#x_train, x_test, y_train, y_test = train_test_split(train.drop('id','claim'))

# %%
x_train = train.drop(['id','claim'], axis = 1)
y_train = train['claim']
x_test = test.drop('id', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-adcbdb451600> in <module>
#       1 x_train = train.drop(['id','claim'], axis = 1)
#       2 y_train = train['claim']
# ----> 3 test.drop('id', axis = 1, inplace = True)
#       4 test
#
# C:\ProgramData\Anaconda3\envs\ssu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramData\Anaconda3\envs\ssu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
train['f1'] = train['f1'].fillna(train['f1'].mean())
features = x_train.columns.values.tolist()
features
# Out:
# ['f1',
#  'f2',
#  'f3',
#  'f4',
#  'f5',
#  'f6',
#  'f7',
#  'f8',
#  'f9',
#  'f10',
#  'f11',
#  'f12',
#  'f13',
#  'f14',
#  'f15',
#  'f16',
#  'f17',
#  'f18',
#  'f19',
#  'f20',
#  'f21',
#  'f22',
#  'f23',
#  'f24',
#  'f25',
#  'f26',
#  'f27',
#  'f28',
#  'f29',
#  'f30',
#  'f31',
#  'f32',
#  'f33',
#  'f34',
#  'f35',
#  'f36',
#  'f37',
#  'f38',
#  'f39',
#  'f40',
#  'f41',
#  'f42',
#  'f43',
#  'f44',
#  'f45',
#  'f46',
#  'f47',
#  'f48',
#  'f49',
#  'f50',
#  'f51',
#  'f52',
#  'f53',
#  'f54',
#  'f55',
#  'f56',
#  'f57',
#  'f58',
#  'f59',
#  'f60',
#  'f61',
#  'f62',
#  'f63',
#  'f64',
#  'f65',
#  'f66',
#  'f67',
#  'f68',
#  'f69',
#  'f70',
#  'f71',
#  'f72',
#  'f73',
#  'f74',
#  'f75',
#  'f76',
#  'f77',
#  'f78',
#  'f79',
#  'f80',
#  'f81',
#  'f82',
#  'f83',
#  'f84',
#  'f85',
#  'f86',
#  'f87',
#  'f88',
#  'f89',
#  'f90',
#  'f91',
#  'f92',
#  'f93',
#  'f94',
#  'f95',
#  'f96',
#  'f97',
#  'f98',
#  'f99',
#  'f100',
# ...

# %%
for feature in features:
    x_train[feature] = x_train[feature].fillna(x_train[feature].mean())
    x_test[feature] = x_test[feature].fillna(x_train[feature].mean())

# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np
dt_clf = DecisionTreeClassifier()
dt_clf.fit(x_train, y_train)
pred = dt_clf.predict(x_test)
pred
# Out:
# array([0, 1, 1, ..., 0, 0, 1], dtype=int64)

# %%
len(pred)
# Out:
# 493474

# %%
test = pd.read_csv('kaggle9/test.csv')

# %%
test['claim'] = pred
final = test[['id', 'claim']]

# %%
final.to_csv(r'F:/kaggle9.csv',encoding='UTF-8', index=False)
